# %%
# Here are 20 Python Practises questions focusing on Print, Variables, User Input, and Data Types for Data Engineering scenarios:

# %%
""" 
    Question 1: Basic User Profile
    Create a program that asks for a user's name and age, stores them in variables, and prints a greeting message.
""" 
user_name = str(input("We want Your good name please provide it : "))
user_age = int(input("Now Enter Your Age : "))
print("so your Name is :",user_name)
print("your age is",user_age,"Right")
# Out:
# so your Name is : Tahir Zaman
# your age is 21 Right

# %%
""" 
    Question 2: Data Type Conversion for Age Calculation
    Create a program that calculates the user's birth year from their age.
"""
current_year = 2026
user_name = str(input("Entre Your Name"))
user_age = int(input("Enter Age "))

Birth_year = current_year - user_age
print(user_name,"Was Born in",Birth_year)
# Out:
# Tahir Zaman Was Born in 2003
